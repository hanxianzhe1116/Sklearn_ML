# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import sys
import warnings
warnings.filterwarnings("ignore")
plt.rcParams['font.sans-serif'] = ['SimHei']  # 用来正常显示中文标签
plt.rcParams['axes.unicode_minus'] = False  # 用来正常显示负号

# %%
data_285 = pd.read_excel("285号样本原始数据整合.xlsx", na_values=np.nan, skiprows=1)

# %%
data_285.shape
# Out:
# (40, 355)

# %%
data_285.head()
# Out:
#                      时间  S-ZORB.CAL_H2.PV  S-ZORB.PDI_2102.PV  \
# 0   2017-07-17 06:03:00          0.273498            24.17817
# 1   2017-07-17 06:06:00          0.273493            24.17971
# 2   2017-07-17 06:09:00          0.273488            24.18125
# 3   2017-07-17 06:12:00          0.273483            24.18279
# 4   2017-07-17 06:15:00          0.273478            24.18434
#
#    S-ZORB.PT_2801.PV  S-ZORB.FC_2801.PV  S-ZORB.TE_2103.PV  S-ZORB.TE_2005.PV  \
# 0           2.528462           856.2485           421.5055           421.1933
# 1           2.528483           856.2297           421.5057           421.1934
# 2           2.528504           856.2109           421.5059           421.1936
# 3           2.528525           856.1922           421.5061           421.1937
# 4           2.528546           856.1734           421.5063           421.1939
#
#    S-ZORB.PT_2101.PV  S-ZORB.PDT_2104.PV  S-ZORB.SIS_PDT_2103B.PV  ...  \
# ...

# %%
# ser1表示传入DataFrame的某一列
error_value_list = []
def three_sigma(ser1):
    # 求平均值
    mean_value = ser1.mean()
    # 求标准差
    std_value = ser1.std()
    # 位于(μ-3σ,μ+3σ)区间内的数据是正常的，不在该区间的数据是异常的
    # ser1中的数值小于μ-3σ或大于μ+3σ均为异常值
    # 一旦发现异常值就标注为True，否则标注为False
    rule = (mean_value - 3 * std_value > ser1) | (mean_value + 3 * std_value < ser1)
    #print(rule)
    if rule is True:
        # 返回异常值的位置索引
        index = np.arange(ser1.shape[0])[rule]
        error_value_list.append(index)
    return error_value_list

# %%
error_value_count = 0

for i in range(1, len(data_285.columns)):
    error_value_list = three_sigma(data_285[data_285.columns[i]])
    for j in range(len(error_value_list)):
        print(data_285[data_285.columns[i]].iloc[error_value_list[j]])
        error_value_count += 1
if error_value_count == 0:
    print("285号样本原始数据中不含异常值！")
else:
    print("285号样本原始数据中共含有" + str(error_value_count) + "个异常值！")
# Out:
# 285号样本原始数据中不含异常值！

# %%
data_313 = pd.read_excel("313号样本原始数据整合.xlsx", na_values=np.nan, skiprows=1)

# %%
data_313.shape
# Out:
# (40, 355)

# %%
data_313.head()
# Out:
#                      时间  S-ZORB.CAL_H2.PV  S-ZORB.PDI_2102.PV  \
# 0   2017-05-15 06:03:00          0.261208            17.06828
# 1   2017-05-15 06:06:00          0.260958            16.86597
# 2   2017-05-15 06:09:00          0.260708            16.66366
# 3   2017-05-15 06:12:00          0.262787            17.59503
# 4   2017-05-15 06:15:00          0.266825            18.00510
#
#    S-ZORB.PT_2801.PV  S-ZORB.FC_2801.PV  S-ZORB.TE_2103.PV  S-ZORB.TE_2005.PV  \
# 0           2.414703           838.6098           420.2411           419.6024
# 1           2.412846           838.8535           420.7948           420.3819
# 2           2.410989           839.0970           421.3485           421.1614
# 3           2.419262           841.1829           422.3332           421.9007
# 4           2.417170           866.1335           422.3154           422.3370
#
#    S-ZORB.PT_2101.PV  S-ZORB.PDT_2104.PV  S-ZORB.SIS_PDT_2103B.PV  ...  \
# ...

# %%
error_value_count = 0

for i in range(1, len(data_313.columns)):
    error_value_list = three_sigma(data_313[data_285.columns[i]])
    for j in range(len(error_value_list)):
        print(data_313[data_313.columns[i]].iloc[error_value_list[j]])
        error_value_count += 1
if error_value_count == 0:
    print("313号样本原始数据中不含异常值！")
else:
    print("313号样本原始数据中共含有" + str(error_value_count) + "个异常值！")
# Out:
# 313号样本原始数据中不含异常值！

# %%
data_285 = data_285.drop(['时间'], axis=1)
data_313 = data_313.drop(['时间'], axis=1)

# %%
data_285.head()
# Out:
#    S-ZORB.CAL_H2.PV  S-ZORB.PDI_2102.PV  S-ZORB.PT_2801.PV  S-ZORB.FC_2801.PV  \
# 0          0.273498            24.17817           2.528462           856.2485
# 1          0.273493            24.17971           2.528483           856.2297
# 2          0.273488            24.18125           2.528504           856.2109
# 3          0.273483            24.18279           2.528525           856.1922
# 4          0.273478            24.18434           2.528546           856.1734
#
#    S-ZORB.TE_2103.PV  S-ZORB.TE_2005.PV  S-ZORB.PT_2101.PV  \
# 0           421.5055           421.1933           2.426675
# 1           421.5057           421.1934           2.426696
# 2           421.5059           421.1936           2.426718
# 3           421.5061           421.1937           2.426739
# 4           421.5063           421.1939           2.426760
#
#    S-ZORB.PDT_2104.PV  S-ZORB.SIS_PDT_2103B.PV  S-ZORB.TC_2101.PV  ...  \
# ...

# %%
data_313.head()
# Out:
#    S-ZORB.CAL_H2.PV  S-ZORB.PDI_2102.PV  S-ZORB.PT_2801.PV  S-ZORB.FC_2801.PV  \
# 0          0.261208            17.06828           2.414703           838.6098
# 1          0.260958            16.86597           2.412846           838.8535
# 2          0.260708            16.66366           2.410989           839.0970
# 3          0.262787            17.59503           2.419262           841.1829
# 4          0.266825            18.00510           2.417170           866.1335
#
#    S-ZORB.TE_2103.PV  S-ZORB.TE_2005.PV  S-ZORB.PT_2101.PV  \
# 0           420.2411           419.6024           2.313425
# 1           420.7948           420.3819           2.311459
# 2           421.3485           421.1614           2.309492
# 3           422.3332           421.9007           2.317966
# 4           422.3154           422.3370           2.315674
#
#    S-ZORB.PDT_2104.PV  S-ZORB.SIS_PDT_2103B.PV  S-ZORB.TC_2101.PV  ...  \
# ...

# %%
data_285 = data_285.append(data_285.mean(), ignore_index=True)
data_313 = data_313.append(data_313.mean(), ignore_index=True)

# %%
data_285.tail(1)
# Out:
#     S-ZORB.CAL_H2.PV  S-ZORB.PDI_2102.PV  S-ZORB.PT_2801.PV  \
# 40          0.273399           24.208241            2.52887
#
#     S-ZORB.FC_2801.PV  S-ZORB.TE_2103.PV  S-ZORB.TE_2005.PV  \
# 40         855.882523         421.509325         421.196235
#
#     S-ZORB.PT_2101.PV  S-ZORB.PDT_2104.PV  S-ZORB.SIS_PDT_2103B.PV  \
# 40           2.427093           59.703011              1108.285375
#
#     S-ZORB.TC_2101.PV  ...  S-ZORB.CAL_1.CANGLIANG.PV  S-ZORB.FT_1006.DACA.PV  \
# 40         244.121748  ...                   2.358559               3321.5832
#
#     S-ZORB.FT_5204.DACA.PV  S-ZORB.FT_1006.TOTALIZERA.PV  \
# 40                190.6942                   98944916.75
#
#     S-ZORB.FT_5204.TOTALIZERA.PV  S-ZORB.FT_1503.DACA.PV  \
# 40                     2433448.0               2200.7891
#
#     S-ZORB.FT_1503.TOTALIZERA.PV  S-ZORB.FT_1504.DACA.PV  \
# 40                     5149259.0               2846.8966
#
#     S-ZORB.FT_1504.TOTALIZERA.PV  S-ZORB.PC_1001A.PV
# ...

# %%
data_313.tail(1)
# Out:
#     S-ZORB.CAL_H2.PV  S-ZORB.PDI_2102.PV  S-ZORB.PT_2801.PV  \
# 40          0.261936           17.183467           2.417056
#
#     S-ZORB.FC_2801.PV  S-ZORB.TE_2103.PV  S-ZORB.TE_2005.PV  \
# 40         850.300855         424.968595         424.522167
#
#     S-ZORB.PT_2101.PV  S-ZORB.PDT_2104.PV  S-ZORB.SIS_PDT_2103B.PV  \
# 40           2.315898           61.701366                1250.6929
#
#     S-ZORB.TC_2101.PV  ...  S-ZORB.CAL_1.CANGLIANG.PV  S-ZORB.FT_1006.DACA.PV  \
# 40         245.333915  ...                   2.894837            10013.864775
#
#     S-ZORB.FT_5204.DACA.PV  S-ZORB.FT_1006.TOTALIZERA.PV  \
# 40              147.165737                   87939278.25
#
#     S-ZORB.FT_5204.TOTALIZERA.PV  S-ZORB.FT_1503.DACA.PV  \
# 40                   2205865.275             1943.691157
#
#     S-ZORB.FT_1503.TOTALIZERA.PV  S-ZORB.FT_1504.DACA.PV  \
# 40                     2149491.8             2501.854175
#
#     S-ZORB.FT_1504.TOTALIZERA.PV  S-ZORB.PC_1001A.PV
# ...

# %%
data_285.to_excel("285样本处理完毕数据.xlsx", index=False)
data_313.to_excel("313样本处理完毕数据.xlsx", index=False)
